# %% [markdown]
# In this lab, we will use 'twarc' Python package to interact with Twitter API v2.
#
# We will use Search Tweets --> Recent search (endpoint)
#
# This API endpoint:
# - (By default) Retrieves 10 tweets in the recent 7 days
# - (By setting max_results to 100) Can retrieve up to 100 tweets per API request
#
# Ref: https://twarc-project.readthedocs.io/en/latest/api/client2/#twarc.client2.Twarc2.search_recent
#
# Ref: https://www.youtube.com/watch?v=guHH51GDDI0
#
# Ref: https://catriscode.com/2021/05/01/tweets-cleaning-with-python/

# %%
import plotly.graph_objects as go
from twarc import Twarc2

# %%
# Paste in your own bearer token below
client = Twarc2(
    bearer_token = "AAAAAAAAAAAAAAAAAAAAAEjdYQEAAAAAkJoz3KdGyA3t7KXLGHAKCpyBYPE%3DPAmIsAmXqs1ijHFZZnHHSkN7IQGrNyKzio8Igq6BAYpOkhWIqn"
)

# %%
query = 'omicron lang=en '

# %%
import datetime

results = client.search_recent(
    query=query,
    max_results=100,
    tweet_fields="author_id,context_annotations"
)

# %%
for page in results:
    print("======================")
    print(page)
    data = page['data']
# Out:
# ======================
# {'data': [{'referenced_tweets': [{'type': 'quoted', 'id': '1233134710638825473'}, {'type': 'replied_to', 'id': '1488286842026065920'}], 'in_reply_to_user_id': '84292551', 'text': '@TummyJimmy @Diviance1 @mattdpearce Here\'s what they said then:\nhttps://t.co/ZIJ69DU7dW\n\nHere\'s what they say now:\nhttps://t.co/unNTecqIYb\n\nLike I said, what is once "misinformation" often becomes reality as reality changes &amp; more is learned', 'entities': {'mentions': [{'start': 0, 'end': 11, 'username': 'TummyJimmy', 'id': '84292551'}, {'start': 12, 'end': 22, 'username': 'Diviance1', 'id': '81888124'}, {'start': 23, 'end': 35, 'username': 'mattdpearce', 'id': '69004966'}]}, 'context_annotations': [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '1054479510219845632', 'name': 'Matt Pearce', 'description': 'Matt Pearce'}}, {'domain': {'id': '94', 'name': 'Journalist', 'description': "A journalist like 'Anderson Cooper'"}, 'entity': {'id': '1054479510219845632', 'name': 'Matt Pearce', 'description': 'Matt Pearce'}}, {'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'author_id': '2450238156', 'id': '1488301766592585731'}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1488165888675176450'}], 'text': 'RT @cint: https://t.co/c1SEviKkAw\n#Dutch #covid19 January 31 in #independent #interactive #dashboard.\n\nPositive #cases #RIVM: +112227 (4.43…', 'entities': {'mentions': [{'start': 3, 'end': 8, 'username': 'cint', 'id': '17229748'}]}, 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'author_id': '17229748', 'id': '1488211002680397826'}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1488165888675176450'}], 'text': 'RT @cint: https://t.co/c1SEviKkAw\n#Dutch #covid19 January 31 in #independent #interactive #dashboard.\n\nPositive #cases #RIVM: +112227 (4.43…', 'entities': {'mentions': [{'start': 3, 'end': 8, 'username': 'cint', 'id': '17229748'}]}, 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'author_id': '1197472679672070146', 'id': '1488167139626389504'}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1488165888675176450'}], 'text': 'RT @cint: https://t.co/c1SEviKkAw\n#Dutch #covid19 January 31 in #independent #interactive #dashboard.\n\nPositive #cases #RIVM: +112227 (4.43…', 'entities': {'mentions': [{'start': 3, 'end': 8, 'username': 'cint', 'id': '17229748'}]}, 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'author_id': '628312859', 'id': '1488166157538447363'}, {'text': 'https://t.co/c1SEviKkAw\n#Dutch #covid19 January 31 in #independent #interactive #dashboard.\n\nPositive #cases #RIVM: +112227 (4.432.484)\nIn #Hospital NICE from 12:00 AM: +20 (80.287)\n#Deaths: +5 (21.277)\n\n#Netherlands #Lockdown #corona #BoosterJab #StaySafe #Omicron #2G #WHO https://t.co/PBn7rNiNzP', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'attachments': {'media_keys': ['3_1488165317461356548']}, 'author_id': '17229748', 'id': '1488165888675176450'}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1487794819607015425'}], 'text': 'RT @cint: https://t.co/c1SEviKkAw\n#Dutch #covid19 January 30 in #interactive #dashboard, the Smart Graph\n\nPositive #cases #RIVM: +75164 (4.…', 'entities': {'mentions': [{'start': 3, 'end': 8, 'username': 'cint', 'id': '17229748'}]},  ...
# ======================
# {'data': [{'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'author_id': '230103956', 'id': '1486463859506483207', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…'}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'author_id': '25873465', 'id': '1486462513470398467', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…'}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'author_id': '1300379062918164480', 'id': '1486461984040173578', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…'}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'author_id': '426103650', 'id': '1486461494816559104', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…'}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'author_id': '1083153770152890368', 'id': '1486461367746023436', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…'}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'author_id': '912962383785623552', 'id': '1486460955492032512', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…'}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'author_id': '1241426833582821376', 'id': '1486459179581816842', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccinat ...
# ======================
# {'data': [{'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'id': '1486392469445128193', 'author_id': '925850513761030149', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'id': '1486392119971434499', 'author_id': '1389278326418726914', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'id': '1486390662845059072', 'author_id': '2999947670', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'id': '1486389713040723969', 'author_id': '82358429', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'id': '1486389435767963653', 'author_id': '176352444', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486344383792177154'}], 'entities': {'mentions': [{'start': 3, 'end': 8, 'username': 'cint', 'id': '17229748'}]}, 'text': 'RT @cint: https://t.co/c1SEvisJbW\n#Dutch #covid19 January 26 #interactive #Dashboard\nPositive #cases: +58616 (4.067.075)\nIn #Hospital NICE…', 'id': '1486387799863484419', 'author_id': '17229748', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'id': '1486385232832045058', 'author_id': '3380299043', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, ' ...
# ======================
# {'data': [{'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'author_id': '906612331', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'id': '1486317903385350148', 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…'}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'author_id': '361398754', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'id': '1486316751570747402', 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…'}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'author_id': '2800892579', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'id': '1486312378455273473', 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…'}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'author_id': '20231111', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'id': '1486310992015466503', 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…'}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'author_id': '791644933', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'id': '1486309543533551619', 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…'}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'author_id': '417365324', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'id': '1486308410144567298', 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…'}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'author_id': '4537015863', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'id': '1486307828461719553', 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms hi ...
# ======================
# {'data': [{'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'author_id': '1186021935534215172', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'id': '1486268086034571267', 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'author_id': '1199731875947962373', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'id': '1486266991283429383', 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'author_id': '53889094', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'id': '1486266701922680834', 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'author_id': '2244721547', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'id': '1486266167081811968', 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'author_id': '128269377', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'id': '1486265393782181889', 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'author_id': '2714211823', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'id': '1486265362614304769', 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'author_id': '352125308', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'id': '1486265185232990212', 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'entities': {'mentions': [{' ...

# %%
len(data)
# Out:
# 83

# %%
# Convert JSON into Pandas data frame

import pandas as pd

df = pd.json_normalize(data)

df
# Out:
#                                     referenced_tweets            author_id  \
# 0   [{'type': 'retweeted', 'id': '1486253804270010...  1186021935534215172
# 1   [{'type': 'retweeted', 'id': '1486253804270010...  1199731875947962373
# 2   [{'type': 'retweeted', 'id': '1486253804270010...             53889094
# 3   [{'type': 'retweeted', 'id': '1486253804270010...           2244721547
# 4   [{'type': 'retweeted', 'id': '1486253804270010...            128269377
# ..                                                ...                  ...
# 78  [{'type': 'retweeted', 'id': '1486056951297499...            628312859
# 79                                                NaN             17229748
# 80                                                NaN  1450393476722536449
# 81                                                NaN  1450393476722536449
# 82                                                NaN            298689306
#
#                                   context_annotations                   id  \
# 0   [{'domain': {'id': '123', 'name': 'Ongoing New...  1486268086034571267
# 1   [{'domain': {'id': '123', 'name': 'Ongoing New...  1486266991283429383
# 2   [{'domain': {'id': '123', 'name': 'Ongoing New...  1486266701922680834
# 3   [{'domain': {'id': '123', 'name': 'Ongoing New...  1486266167081811968
# 4   [{'domain': {'id': '123', 'name': 'Ongoing New...  1486265393782181889
# ..                                                ...                  ...
# 78  [{'domain': {'id': '123', 'name': 'Ongoing New...  1486057067492352004
# 79  [{'domain': {'id': '123', 'name': 'Ongoing New...  1486056951297499143
# 80  [{'domain': {'id': '123', 'name': 'Ongoing New...  1486048574634930177
# 81  [{'domain': {'id': '123', 'name': 'Ongoing New...  1486040278293172225
# 82  [{'domain': {'id': '123', 'name': 'Ongoing New...  1485912480782196737
#
#                                                  text  \
# 0   RT @chrischirp: French academy of medicine urg...
# 1   RT @chrischirp: French academy of medicine urg...
# 2   RT @chrischirp: French academy of medicine urg...
# 3   RT @chrischirp: French academy of medicine urg...
# 4   RT @chrischirp: French academy of medicine urg...
# ..                                                ...
# 78  RT @cint: https://t.co/c1SEviKkAw\n#Dutch #cov...
# 79  https://t.co/c1SEviKkAw\n#Dutch #covid19 Janua...
# 80  Russian drug effective against both Delta &amp...
# 81  CDC says it exaggerated Omicron’s spread https...
# 82  South Korea's daily coronavirus cases hit a re...
#
#                                     entities.mentions   attachments.media_keys
# 0   [{'start': 3, 'end': 14, 'username': 'chrischi...                      NaN
# 1   [{'start': 3, 'end': 14, 'username': 'chrischi...                      NaN
# 2   [{'start': 3, 'end': 14, 'username': 'chrischi...                      NaN
# 3   [{'start': 3, 'end': 14, 'username': 'chrischi...                      NaN
# 4   [{'start': 3, 'end': 14, 'username': 'chrischi...                      NaN
# ..                                                ...                      ...
# 78  [{'start': 3, 'end': 8, 'username': 'cint', 'i...                      NaN
# 79                                                NaN  [3_1486056919995494405]
# 80                                                NaN                      NaN
# 81                                                NaN                      NaN
# 82                                                NaN  [3_1485912479721000962]
#
# [83 rows x 7 columns]

# %%
# Let's retrieve just the text from each tweet
# Store each tweet text as a List item

tweet_text_list = df['text'].tolist()

tweet_text_list
# Out:
# ['RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and how Omicron is surging through this age group. \n\nWhere are our medical societies?\n\nhttps://t.co/PpegTj0Lso https://t.co/bDB2UKsjcL https://t.co/FdDt7wH2JK',
#  'RT @cint: https://t.co/c1SEviKkAw\n#Dutch #covid19 January 25 #interactive #Dashboard\nPositive #cases: +54160 (4.008.459)\nIn #Hospital, NICE…',
#  'RT @cint: https://t.co/c1SEviKkAw\n#Dutch #covid19 January 25 #interactive #Dashboard\nPositive #cases: +54160 (4.008.459)\nIn #Hospital, NICE…',
#  'https://t.co/c1SEviKkAw\n#Dutch #covid19 January 25 #interactive #Dashboard\nPositive #cases: +54160 (4.008.459)\nIn #Hospital, NICE from 12:00 AM: +20 (79.335)\n#Deaths: +8 (21.227)\nClick in the #graphics to select #data \n#Netherlands #Lockdown #corona #BoosterJab #StaySafe #Omicron https://t.co/SXd4aoSahK',
#  'Russian drug effective against both Delta &amp; Omicron –\xa0scientists https://t.co/aI7WKVDBgB',
#  'CDC says it exaggerated Omicron’s\xa0spread https://t.co/XB8jvx7ODQ',
#  "South Korea's daily coronavirus cases hit a record high of 8,571, driven by the fast spread of the new dominant omicron variant. #QNA \nhttps://t.co/HA50TvfKHN https://t.co/GzFcqxxYjv"]

# %%
'''
1) Lowercasing all the letters

This step is important to make sure that all your letters are in uniform.

temp = tweet.lower()
temp
'''
# Out:
# '\n1) Lowercasing all the letters\n\nThis step is important to make sure that all your letters are in uniform.\n\ntemp = tweet.lower()\ntemp\n'

# %%
'''
2) Removing hashtags and mentions

Hashtags and mentions are common in tweets.
There are cases where you want to remove them so you only get the 
clean content of a tweet without all these elements.

You can remove these hashtags and mentions using regex.

import re

temp = re.sub("@[A-Za-z0-9_]+","", temp)
temp = re.sub("#[A-Za-z0-9_]+","", temp)
temp
'''
# Out:
# '\n2) Removing hashtags and mentions\n\nHashtags and mentions are common in tweets.\nThere are cases where you want to remove them so you only get the \nclean content of a tweet without all these elements.\n\nYou can remove these hashtags and mentions using regex.\n\nimport re\n\ntemp = re.sub("@[A-Za-z0-9_]+","", temp)\ntemp = re.sub("#[A-Za-z0-9_]+","", temp)\ntemp\n'

# %%
'''
3) Removing links

Links are usually not necessary for text processing, so it’s
better to remove them from your text.

temp = re.sub(r"http\S+", "", temp)
temp = re.sub(r"www.\S+", "", temp)
temp
'''
# Out:
# '\n3) Removing links\n\nLinks are usually not necessary for text processing, so it’s\nbetter to remove them from your text.\n\ntemp = re.sub(r"http\\S+", "", temp)\ntemp = re.sub(r"www.\\S+", "", temp)\ntemp\n'

# %%
'''
4) Removing punctuations

Depending on your needs, you may not need punctuations such as
period, comma, exclamation mark, question mark, etc.

temp = re.sub('[()!?]', ' ', temp)
temp = re.sub('\[.*?\]',' ', temp)
temp
'''
# Out:
# "\n4) Removing punctuations\n\nDepending on your needs, you may not need punctuations such as\nperiod, comma, exclamation mark, question mark, etc.\n\ntemp = re.sub('[()!?]', ' ', temp)\ntemp = re.sub('\\[.*?\\]',' ', temp)\ntemp\n"

# %%
'''
5) Filtering non-alphanumeric characters

The previous step may have removed the punctuations, including all the
non-alphanumeric characters, but just to be sure, we can remove all letters
except the alphabets (a-z) and numbers (0-9). The sign ^ below means except.

temp = re.sub("[^a-z0-9]"," ", temp)
temp
'''
# Out:
# '\n5) Filtering non-alphanumeric characters\n\nThe previous step may have removed the punctuations, including all the\nnon-alphanumeric characters, but just to be sure, we can remove all letters\nexcept the alphabets (a-z) and numbers (0-9). The sign ^ below means except.\n\ntemp = re.sub("[^a-z0-9]"," ", temp)\ntemp\n'

# %%
'''
6) Tokenization

In tokenization, you basically tokenize your text into tokens.

And what is a token? In this case, you split your text into smaller components,
for example a paragraph into a list of sentences, or a sentence into a list of words.

Library such as nltk provides functions such as word_tokenize() or sent_tokenize()
to help you with this.

However, if you just want a simple tokenizing step where you split your text 
into words into a list, then you can do it as simple as the following code.

The result will give you a list of words from your text.

temp = temp.split()
temp
'''
# Out:
# '\n6) Tokenization\n\nIn tokenization, you basically tokenize your text into tokens.\n\nAnd what is a token? In this case, you split your text into smaller components,\nfor example a paragraph into a list of sentences, or a sentence into a list of words.\n\nLibrary such as nltk provides functions such as word_tokenize() or sent_tokenize()\nto help you with this.\n\nHowever, if you just want a simple tokenizing step where you split your text \ninto words into a list, then you can do it as simple as the following code.\n\nThe result will give you a list of words from your text.\n\ntemp = temp.split()\ntemp\n'

# %%
'''
7) Stop words removal

Stop words are words that are considered unimportant to the meaning of a text.
These words may seem important to us, humans, but to machine these words may be
considered nuisance to the processing steps.

It’s also important to keep in mind that stop words are largely language-dependent.
In English, you have stop words such as for, to, and, or, in, out, etc.

Here I first defined a list of stop words in English.
Then, I match each token with each stop word.

If a token isn’t found in the list of stop words, the token gets saved,
otherwise it’s not saved. In the end, you join all the words into one text again.


stopwords = ["for", "on", "an", "a", "of", "and", "in", "the", "to", "from"]
 
temp = [w for w in temp if not w in stopwords]
temp = " ".join(word for word in temp)
'''
# Out:
# '\n7) Stop words removal\n\nStop words are words that are considered unimportant to the meaning of a text.\nThese words may seem important to us, humans, but to machine these words may be\nconsidered nuisance to the processing steps.\n\nIt’s also important to keep in mind that stop words are largely language-dependent.\nIn English, you have stop words such as for, to, and, or, in, out, etc.\n\nHere I first defined a list of stop words in English.\nThen, I match each token with each stop word.\n\nIf a token isn’t found in the list of stop words, the token gets saved,\notherwise it’s not saved. In the end, you join all the words into one text again.\n\n\nstopwords = ["for", "on", "an", "a", "of", "and", "in", "the", "to", "from"]\n \ntemp = [w for w in temp if not w in stopwords]\ntemp = " ".join(word for word in temp)\n'

# %%
'''
Text Preprocessing: From Start to Finish

I hope you understand the steps I have explained above.
Now we can combine all those lines of code into one function that we can
call and pass an argument to.

The function then returns a clean text that is ready for you to work with.

Keep in mind that the order of steps here are not absolute.
You can arrange them around depending on your text and your needs.
The code below is what I found to be the most effective on the data I
usually work with, but in case you find another pattern of data,
you can always work them out differently.
'''
import numpy as np
import re

stopwords = ["for", "on", "an", "a", "of", "and", "in", "the", "to", "from"]

def clean_tweet(tweet):
    if type(tweet) == np.float:
        return ""
    temp = tweet.lower()
    temp = re.sub("'", "", temp) # to avoid removing contractions in english
    temp = re.sub("@[A-Za-z0-9_]+","", temp)
    temp = re.sub("#[A-Za-z0-9_]+","", temp)
    temp = re.sub(r'http\S+', '', temp)
    temp = re.sub('[()!?]', ' ', temp)
    temp = re.sub('\[.*?\]',' ', temp)
    temp = re.sub("[^a-z0-9]"," ", temp)
    temp = temp.split()
    temp = [w for w in temp if not w in stopwords]
    temp = " ".join(word for word in temp)
    return temp

# %%
tweets = ["Get ready for #NatGeoEarthDay! Join us on 4/21 for an evening of music and celebration, exploration and inspiration https://on.natgeo.com/3t0wzQy.",
"Coral in the shallows of Aitutaki Lagoon, Cook Islands, Polynesia https://on.natgeo.com/3gkgq4Z",
"Don't miss our @reddit AMA with author and climber Mark Synnott who will be answering your questions about his historic journey to the North Face of Everest TODAY at 12:00pm ET! Start submitting your questions here: https://on.natgeo.com/3ddSkHk @DuttonBooks"]
 
results = [clean_tweet(tw) for tw in tweets]
results
# Out:
# /var/folders/5z/tmp48bwn5lx0cw1mmf31bzgm0000gn/T/ipykernel_55045/1029021058.py:22: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if type(tweet) == np.float:
# ['get ready join us 4 21 evening music celebration exploration inspiration',
#  'coral shallows aitutaki lagoon cook islands polynesia',
#  'dont miss our ama with author climber mark synnott who will be answering your questions about his historic journey north face everest today at 12 00pm et start submitting your questions here']

# %%
# Let's go and apply this to our own tweets
my_results = [clean_tweet(tw) for tw in tweet_text_list]
my_results
# Out:
# /var/folders/5z/tmp48bwn5lx0cw1mmf31bzgm0000gn/T/ipykernel_55045/1029021058.py:22: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if type(tweet) == np.float:
# ['rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine how omicron is surging through this age group where are our medical societies',
#  'rt january 25 positive 54160 4 008 459 nice',
#  'rt january 25 positive 54160 4 008 459 nice',
#  'january 25 positive 54160 4 008 459 nice 12 00 am 20 79 335 8 21 227 click select',
#  'russian drug effective against both delta amp omicron scientists',
#  'cdc says it exaggerated omicron s spread',
#  'south koreas daily coronavirus cases hit record high 8 571 driven by fast spread new dominant omicron variant']

# %%
# importing all necessary modules

# Note that wordcloud package also provides a stop word list
# We won't be using it here - but please do explore!!!
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

comment_words = ''

# iterate through list
for tweet_text in results:
    # split the text into tokens
    tokens = tweet_text.split()
    # Append tokens to string comment_words
    comment_words += " ".join(tokens)+" "
    
# Let's make a word cloud
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                #stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
